# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0      ilulissat  69.2167  -51.1000    278.51        64          83
# 1        1        aasiaat  68.7098  -52.8699    276.43        92          98
# 2        2  komsomol'skiy  43.9783   46.6985    300.84        41           0
# 3        3         bukama  -9.2000   25.8500    303.09        19          26
# 4        4       kerikeri -35.2268  173.9474    285.32        93          69
#
#    Wind Speed Country        Date
# 0        1.62      GL  1690905410
# 1        1.11      GL  1690905410
# 2        5.78      RU  1690905410
# 3        2.03      CD  1690905712
# 4        0.45      NZ  1690905408

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    x="Lng", 
    y="Lat", 
    c="Humidity",  
    cmap="viridis",  
    size=100,  
    hover_cols=["City", "Humidity"],  
    colorbar=False,    
).opts(toolbar="above", xaxis=None, yaxis=None) 

# Display the map
map_plot
# Out:
# :Points   [Lng,Lat]   (Humidity,City)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_data_df = pd.read_csv("output_data/cities.csv")
ideal_df = city_data_df[
    (city_data_df['Max Temp'] > 21) & (city_data_df['Max Temp'] < 27) &  # Max temperature between 21 and 27 degrees
    (city_data_df['Wind Speed'] < 4.5) &  # Wind speed less than 4.5 m/s
    (city_data_df['Cloudiness'] == 0)
]

# Drop any rows with null values
ideal_df = ideal_df.dropna()
# Display sample data
ideal_df
# Out:
# Empty DataFrame
# Columns: [City_ID, City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df
# Out:
#                 City Country      Lat       Lng  Humidity Hotel Name
# 0          ilulissat      GL  69.2167  -51.1000        64
# 1            aasiaat      GL  68.7098  -52.8699        92
# 2      komsomol'skiy      RU  43.9783   46.6985        41
# 3             bukama      CD  -9.2000   25.8500        19
# 4           kerikeri      NZ -35.2268  173.9474        93
# ..               ...     ...      ...       ...       ...        ...
# 549     port moresby      PG  -9.4431  147.1797        78
# 550  puerto princesa      PH   9.7392  118.7353        89
# 551       vorotynets      RU  56.0603   45.8633        70
# 552       sidi salim      EG  31.2710   30.7867        44
# 553            oyama      JP  36.3000  139.8000        78
#
# [554 rows x 6 columns]

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "type": "hotel",
    "limit": 1,
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{radius}@{longitude},{latitude}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()

    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# ilulissat - nearest hotel: No hotel found
# aasiaat - nearest hotel: No hotel found
# komsomol'skiy - nearest hotel: No hotel found
# bukama - nearest hotel: No hotel found
# kerikeri - nearest hotel: No hotel found
# longyearbyen - nearest hotel: No hotel found
# praia da vitoria - nearest hotel: No hotel found
# nar'yan-mar - nearest hotel: No hotel found
# bethel - nearest hotel: No hotel found
# urangan - nearest hotel: No hotel found
# edinburgh of the seven seas - nearest hotel: No hotel found
# sao joao da barra - nearest hotel: No hotel found
# nova sintra - nearest hotel: No hotel found
# invercargill - nearest hotel: No hotel found
# yellowknife - nearest hotel: No hotel found
# qurayyat - nearest hotel: No hotel found
# grootfontein - nearest hotel: No hotel found
# albany - nearest hotel: No hotel found
# dunedin - nearest hotel: No hotel found
# anadyr - nearest hotel: No hotel found
# adamstown - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display
city_data_with_hotel = pd.merge(city_data_df, hotel_df[['City', 'Hotel Name', 'Country']], on='City', how='left')
# Configure the map plot
map_plot = city_data_with_hotel.hvplot.points(
    x="Lng",
    y="Lat",
    c="Humidity",  
    cmap="viridis",  
    size=city_data_with_hotel["Humidity"] * 0.3,  
    hover_cols=["City", "Humidity", "Hotel Name", "Country"],  
    colorbar=False,  
).opts(toolbar="above", xaxis=None, yaxis=None)
# Display the map
map_plot
# Out:
# :Points   [Lng,Lat]   (Humidity,_size,City,Hotel Name)
